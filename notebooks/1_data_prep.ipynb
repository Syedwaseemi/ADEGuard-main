# %%
import pandas as pd
import glob
import os

# %%
DATA_PATH = "../data/raw"

# %%
# Years to load
#YEARS = [2020, 2021, 2022, 2023, 2024, 2025]
YEARS = [2021]

# -------------------------------
# Helper function: load and merge yearly data
# -------------------------------
def load_vaers_year(year):
    print(f"Loading VAERS data for {year}...")

    data_file = os.path.join(DATA_PATH, f"{year}VAERSDATA.csv")
    symp_file = os.path.join(DATA_PATH, f"{year}VAERSSYMPTOMS.csv")
    vax_file  = os.path.join(DATA_PATH, f"{year}VAERSVAX.csv")

    # Load CSVs
    df_data = pd.read_csv(data_file, encoding="latin-1", low_memory=False)
    df_symp = pd.read_csv(symp_file, encoding="latin-1", low_memory=False)
    df_vax  = pd.read_csv(vax_file, encoding="latin-1", low_memory=False)

    # Merge
    df = df_data.merge(df_symp, on="VAERS_ID", how="left")
    df = df.merge(df_vax, on="VAERS_ID", how="left")

    # Filter only COVID-19 vaccines
    df = df[df["VAX_TYPE"].str.contains("COVID19", na=False)]

    # Add YEAR column
    df["YEAR"] = year

    return df

# -------------------------------
# Load all years
# -------------------------------
all_years = [load_vaers_year(y) for y in YEARS]
df_all = pd.concat(all_years, ignore_index=True)
print(f"Raw merged dataset: {df_all.shape}")

# -------------------------------
# Deduplicate per patient (VAERS_ID)
# -------------------------------
symptom_cols = ["SYMPTOM1","SYMPTOM2","SYMPTOM3","SYMPTOM4","SYMPTOM5"]

def join_unique(series):
    """Helper to join unique non-null values into one string"""
    return " | ".join(sorted(set(series.dropna().astype(str))))

df_dedup = (
    df_all.groupby("VAERS_ID")
    .agg({
        "YEAR": "first",
        "AGE_YRS": "first",
        "SEX": "first",
        "SYMPTOM_TEXT": "first",    # narrative is usually same across duplicates
        "HOSPITAL": "first",
        "L_THREAT": "first",
        "DIED": "first",
        "DISABLE": "first",
        "VAX_TYPE": join_unique,
        "VAX_NAME": join_unique,
        "VAX_MANU": join_unique,
        "SYMPTOM1": join_unique,
        "SYMPTOM2": join_unique,
        "SYMPTOM3": join_unique,
        "SYMPTOM4": join_unique,
        "SYMPTOM5": join_unique,
    })
    .reset_index()
)

# -------------------------------
# Clean text
# -------------------------------
def clean_text(text):
    if pd.isna(text):
        return ""
    text = str(text).lower().replace("\n", " ").replace("\r", " ")
    return text

df_dedup["SYMPTOM_TEXT"] = df_dedup["SYMPTOM_TEXT"].apply(clean_text)

# Merge structured symptom columns
#df_dedup["SYMPTOMS_STRUCT"] = df_dedup[symptom_cols].fillna("").agg(" | ".join, axis=1)

# Final narrative field
#df_dedup["FINAL_SYMPTOM_TEXT"] = (
#    df_dedup["SYMPTOM_TEXT"].fillna("") + " | " + df_dedup["SYMPTOMS_STRUCT"]
#)

# -------------------------------
# Keep lean schema for ADEGuard
# -------------------------------
keep_cols = [
    "VAERS_ID", "YEAR", "AGE_YRS", "SEX",
    "VAX_TYPE", "VAX_NAME", "VAX_MANU",
    "SYMPTOM_TEXT","SYMPTOM1",
    "HOSPITAL", "L_THREAT", "DIED", "DISABLE"
]
df_adeguard = df_dedup[keep_cols]

# -------------------------------
# Save outputs
# -------------------------------
df_adeguard.to_csv("covid_vaers_2020_adeguard.csv.gz", index=False, compression="gzip")
df_adeguard.to_parquet("covid_vaers_2020_adeguard.parquet", engine="pyarrow", index=False)

# -------------------------------
# ✅ Sanity Check
# -------------------------------
print("\n--- Sanity Check ---")
print("Total records (deduplicated):", len(df_adeguard))
print("Duplicate VAERS_IDs:", df_adeguard["VAERS_ID"].duplicated().sum())
print("Unique VAERS_IDs:", df_adeguard["VAERS_ID"].nunique())

# Peek at random rows
print("\nSample rows:")
print(df_adeguard.sample(3, random_state=42))

# %%
# !pip install wordcloud
# Out:
# Collecting wordcloud
#   Downloading wordcloud-1.9.4-cp313-cp313-win_amd64.whl.metadata (3.5 kB)
# Requirement already satisfied: numpy>=1.6.1 in c:\users\sugan\appdata\local\programs\python\python313\lib\site-packages (from wordcloud) (1.26.4)
# Requirement already satisfied: pillow in c:\users\sugan\appdata\local\programs\python\python313\lib\site-packages (from wordcloud) (11.0.0)
# Requirement already satisfied: matplotlib in c:\users\sugan\appdata\local\programs\python\python313\lib\site-packages (from wordcloud) (3.9.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\sugan\appdata\local\programs\python\python313\lib\site-packages (from matplotlib->wordcloud) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\sugan\appdata\local\programs\python\python313\lib\site-packages (from matplotlib->wordcloud) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\sugan\appdata\local\programs\python\python313\lib\site-packages (from matplotlib->wordcloud) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\sugan\appdata\local\programs\python\python313\lib\site-packages (from matplotlib->wordcloud) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in c:\users\sugan\appdata\local\programs\python\python313\lib\site-packages (from matplotlib->wordcloud) (24.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\sugan\appdata\local\programs\python\python313\lib\site-packages (from matplotlib->wordcloud) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\sugan\appdata\local\programs\python\python313\lib\site-packages (from matplotlib->wordcloud) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\sugan\appdata\local\programs\python\python313\lib\site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)
# Downloading wordcloud-1.9.4-cp313-cp313-win_amd64.whl (300 kB)
# Installing collected packages: wordcloud
# Successfully installed wordcloud-1.9.4
# WARNING: Ignoring invalid distribution ~ip (C:\Users\sugan\AppData\Local\Programs\Python\Python313\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ip (C:\Users\sugan\AppData\Local\Programs\Python\Python313\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ip (C:\Users\sugan\AppData\Local\Programs\Python\Python313\Lib\site-packages)

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# %%
all_symptoms = df_adeguard['SYMPTOMS_STRUCT'].head(50).tolist()

# %%
all_symptoms
# Out:
# ['Pulmonary embolism |  |  |  | ',
#  'Ear discomfort | Feeling abnormal | Ear pruritus | Pruritus | Laboratory test normal | Tinnitus | Rash | Tinnitus',
#  'Abdominal pain | Diverticulitis | Abscess | Blood test | Computerised tomogram abdomen | Computerised tomogram pelvis',
#  'Hypoaesthesia | Injection site hypoaesthesia |  |  | ',
#  'Headache |  |  |  | ',
#  'Erythema | Feeling hot | Flushing |  | ',
#  'Dizziness | Electrocardiogram normal | Hyperhidrosis | Laboratory test normal | Presyncope',
#  'Dysgeusia | Sensory disturbance | Oral pruritus | Tremor | Paraesthesia | Paraesthesia oral | Parosmia',
#  'Chest discomfort | Dyspnoea | Chills | Feeling abnormal | Defaecation urgency | Flushing | Diarrhoea | Presyncope | Dizziness',
#  'Anxiety | Chest pain | Cyanosis | Pollakiuria | Blood pressure systolic increased | Dyspnoea | Feeling abnormal | Sensory disturbance | Chest discomfort | Feeling abnormal | Flushing | Chills | Intensive care | Cold sweat | Pallor',
#  'Headache | Pain |  |  | ',
#  'Blood pressure increased | Dizziness | Nausea | Rash | Dizziness | Dyspnoea | Urticaria | Dyspnoea | Headache | Erythema | Heart rate increased | Headache | Nausea',
#  'Blood pressure increased | Dizziness | Feeling hot | Nausea | Visual impairment',
#  'Blood pressure increased | Dizziness | Dizziness | Flushing | Flushing | Heart rate increased | ',
#  'Blood pressure increased | Skin warm | Ear discomfort | Flushing | Palpitations | Paraesthesia',
#  'Paraesthesia oral | Throat tightness |  |  | ',
#  'Inappropriate schedule of product administration |  |  |  | ',
#  'Eye pruritus | Feeling hot | Paraesthesia | Paraesthesia oral | ',
#  'Asthenia | Impaired driving ability | Fatigue | Limb discomfort | Feeling abnormal | Nervousness | Heart rate increased | Hypertension',
#  'Alanine aminotransferase increased | Blood glucose normal | C-reactive protein normal | Dizziness | Full blood count abnormal | Hyperhidrosis | Hypokalaemia | Pulse abnormal | Troponin normal | Anaphylactic reaction | Blood test | Dizziness | Dyspnoea | Hyperhidrosis | Intensive care | Pulse abnormal | Rash erythematous | Aspartate aminotransferase increased | Dyspnoea | Erythema | Hyperventilation | Hypokalaemia | Metabolic function test abnormal | Thyroxine free normal | Tunnel vision | Blood glucose normal | Blood thyroid stimulating hormone normal | Erythema | Flushing | Intensive care | Rash erythematous | Respiratory rate increased | Troponin normal | Blood thyroid stimulating hormone normal | C-reactive protein normal | Flushing | Full blood count normal | Metabolic function test | Thyroxine free normal | Tunnel vision',
#  'Chills | Nausea | Vomiting |  | ',
#  'Injection site pain | Pain in extremity |  |  | ',
#  'Asthenia | Headache | Injection site pain | Malaise | Nausea',
#  'Lip swelling | Swelling face |  |  | ',
#  'Chills | Pyrexia | Fatigue | Vomiting | Feeling of body temperature change | Headache | Nausea',
#  'Feeling hot | Rash |  |  | ',
#  'Dizziness |  |  |  | ',
#  'Chills | Headache | Pain |  | ',
#  'Dizziness | Headache | Oropharyngeal pain |  | ',
#  'Blood pressure fluctuation | Chest discomfort | Fatigue | Injected limb mobility decreased | Paraesthesia | Chest X-ray normal | Cold sweat | Dizziness | Feeling hot | Pain in extremity | Chest discomfort | Condition aggravated | Dysphagia | Heart rate decreased | Palpitations | Dizziness | Dyspnoea | Heart rate increased | Paraesthesia | Electrocardiogram normal | Hyperhidrosis | Nausea | Panic attack | Pharyngeal swelling',
#  'Abdominal pain upper | Injection site erythema | Chills | Pain | Decreased appetite | Pyrexia | Dyspnoea | Retching | Headache',
#  'Injection site erythema | Injection site induration | Local reaction |  | ',
#  'Chills | Fatigue | Injection site pain | Pain | Pyrexia',
#  'Blood glucose normal | Impaired work ability | Dizziness | Nausea | Dysgeusia | Vertigo | Feeling abnormal | Vomiting | Immediate post-injection reaction',
#  'Dizziness |  |  |  | ',
#  'Erythema | Joint swelling | Pruritus | Peripheral swelling | Skin warm | Pruritus | Swelling | ',
#  'Nausea |  |  |  | ',
#  'Dizziness | Hyperhidrosis |  |  | ',
#  'Pain |  |  |  | ',
#  'Chills | Nausea | Pain |  | ',
#  'Fatigue | Headache | Injection site pain | Malaise | ',
#  'Fatigue | Pain in extremity | Somnolence |  | ',
#  'Flushing | Pruritus | Rash |  | ',
#  'Mobility decreased | Pain in extremity |  |  | ',
#  'Peripheral swelling | Rash erythematous | Product administered at inappropriate site | Rash pruritic | Skin warm |  | ',
#  'Dysgeusia | Immediate post-injection reaction | Nausea | Myalgia | Nausea | ',
#  'Abdominal pain upper | Headache | Nausea |  | ',
| Feeling hot | Pain in extremity | Chest discomfort | Condition aggravated | Dysphagia | Heart rate decreased | Palpitations | Dizziness | Dyspnoea | Heart rate increased | Paraesthesia | Electrocardiogram normal | Hyperhidrosis | Nausea | Panic attack | Pharyngeal swelling Abdominal pain upper | Injection site erythema | Chills | Pain | Decreased appetite | Pyrexia | Dyspnoea | Retching | Headache Injection site erythema | Injection site induration | Local reaction |  |  Chills | Fatigue | Injection site pain | Pain | Pyrexia Blood glucose normal | Impaired work ability | Dizziness | Nausea | Dysgeusia | Vertigo | Feeling abnormal | Vomiting | Immediate post-injection reaction Dizziness |  |  |  |  Erythema | Joint swelling | Pruritus | Peripheral swelling | Skin warm | Pruritus | Swelling |  Nausea |  |  |  |  Dizziness | Hyperhidrosis |  |  |  Pain |  |  |  |  Chills | Nausea | Pain |  |  F ...

# %%
# Create a WordCloud object
wordcloud = WordCloud(width=800, height=800,
                      background_color ='white',
                      min_font_size = 10).generate(all_symptoms_string)

# Plot the WordCloud image
plt.figure(figsize=(8, 8), facecolor=None)
plt.imshow(wordcloud)
plt.axis("off")
plt.tight_layout(pad=0)

plt.show()

# %%
df_adeguard['VAX_NAME'].unique()
# Out:
# array(['COVID19 (COVID19 (MODERNA))',
#        'COVID19 (COVID19 (PFIZER-BIONTECH))',
#        'COVID19 (COVID19 (JANSSEN))', 'COVID19 (COVID19 (UNKNOWN))',
#        'COVID19 (COVID19 (MODERNA)) | COVID19 (COVID19 (PFIZER-BIONTECH))',
#        'COVID19 (COVID19 (PFIZER-BIONTECH)) | COVID19 (COVID19 (UNKNOWN))',
#        'COVID19 (COVID19 (MODERNA)) | COVID19 (COVID19 (UNKNOWN))',
#        'COVID19 (COVID19 (JANSSEN)) | COVID19 (COVID19 (PFIZER-BIONTECH))',
#        'COVID19 (COVID19 (JANSSEN)) | COVID19 (COVID19 (UNKNOWN))',
#        'COVID19 (COVID19 (JANSSEN)) | COVID19 (COVID19 (MODERNA))',
#        'COVID19 (COVID19 (MODERNA)) | COVID19 (COVID19 (PFIZER-BIONTECH)) | COVID19 (COVID19 (UNKNOWN))',
#        'COVID19 (COVID19 (PFIZER-BIONTECH BIVALENT)) | COVID19 (COVID19 (PFIZER-BIONTECH))',
#        'COVID19 (COVID19 (MODERNA BIVALENT)) | COVID19 (COVID19 (MODERNA))',
#        'COVID19 (COVID19 (JANSSEN)) | COVID19 (COVID19 (MODERNA)) | COVID19 (COVID19 (PFIZER-BIONTECH))',
#        'COVID19 (COVID19 (MODERNA BIVALENT)) | COVID19 (COVID19 (PFIZER-BIONTECH BIVALENT)) | COVID19 (COVID19 (PFIZER-BIONTECH))',
#        'COVID19 (COVID19 (JANSSEN)) | COVID19 (COVID19 (MODERNA)) | COVID19 (COVID19 (UNKNOWN))',
#        'COVID19 (COVID19 (JANSSEN)) | COVID19 (COVID19 (NOVAVAX)) | COVID19 (COVID19 (PFIZER-BIONTECH))',
#        'COVID19 (COVID19 (NOVAVAX))',
#        'COVID19 (COVID19 (MODERNA)) | COVID19 (COVID19 (NOVAVAX)) | COVID19 (COVID19 (PFIZER-BIONTECH))',
#        'COVID19 (COVID19 (MODERNA)) | COVID19 (COVID19 (NOVAVAX))',
